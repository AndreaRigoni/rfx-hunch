# %% [markdown]
# # Missing simulated data (1)
#
# This test shows the effect of the simple AEFIT0 autoencoder where I simply set the input as 0 where the nan has been inputed .. It assumes that the missing data is stocastic within the overall array

# %%
import numpy as np
import tensorflow as tf

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors 

import ipysh
import Hunch_utils  as Htls
import Hunch_lsplot as Hplt

import Dummy_g1data as dummy
import models.AEFIT0 as aefit

import os
# Out:
# reload set for module  Hunch_utils
# reload set for module  Hunch_lsplot
# reload set for module  models.AEFIT
# reload set for module  models.AEFIT_v1
# reload set for module  models.AEFIT0
# reload set for module  models.AEFIT1
# reload set for module  models.SPFIT
# reload set for module  Dummy_g1data

# %%
nan_mask = np.zeros([20], dtype=np.int32) 
nan_mask[5]  = 1
nan_mask[10] = 1
nan_mask[11] = 1
nan_mask[12] = 1
nan_mask[16] = 1

ds = dummy.Dummy_g1data(counts=60000, nanmask=nan_mask)

# %%
m = aefit.AEFIT0(latent_dim=2, feature_dim=40)
# Out:
# aefit 0 configured new

# %%
# aefit.test_dummy(m,qsh,batch=200,epoch=10)
m.load(ipysh.abs_builddir+'/kcp/missing_simulated_data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d7fdb17a0875> in <module>()
#       1 # aefit.test_dummy(m,qsh,batch=200,epoch=10)
# ----> 2 m.load(ipysh.abs_builddir+'/kcp/missing_simulated_data')
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/AEFIT0.py in load(self, filename)
#     413
#     414     def load(self, filename):
# --> 415         self.inference_net.load_weights(filename+'_encoder.kcp')
#     416         self.generative_net.load_weights(filename+'_decoder.kcp')
#     417
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name)
#     160         raise ValueError('Load weights is not yet supported with TPUStrategy '
#     161                          'with steps_per_run greater than 1.')
# --> 162     return super(Model, self).load_weights(filepath, by_name)
# ...

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hplt.LSPlotBokeh()
p.set_model(m)
# p.set_data(qsh)
p.set_data(ds)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5297">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:37835/autoload.js?bokeh-autoload-element=5422&bokeh-absolute-url=http://172.17.0.2:37835&resources=none" id="5422"></script>
