# %%
import numpy as np
import tensorflow as tf

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors 

import ipysh
import Hunch_utils  as Htls
import Hunch_lsplot as Hplt
import Hunch_tSNEplot as Hsne

import models.AEFIT0 as aefit

# %aimport Hunch_tSNEplot
# Out:
# reload set for module  Hunch_utils
# reload set for module  Hunch_lsplot
# reload set for module  models.AEFIT
# reload set for module  models.AEFIT_v1
# reload set for module  models.AEFIT0
# reload set for module  models.AEFIT1
# reload set for module  models.SPFIT
# reload set for module  Dummy_g1data

# %%
qsh = Htls.QSH_Dataset()

# %%
import os
file = ipysh.abs_builddir+'/te_db_r15.npy'
if os.path.isfile(file):
    qsh.load(file)
else:
    qsh.load(ipysh.abs_builddir+'/te_db_1.npy')    
    qsh.rebalance_prel(15)
    qsh.save(ipysh.abs_builddir+'/te_db_r15.npy')

# %%
qsh.shuffle()
qsh.filter_number_set(15)
qsh.set_null(np.nan)
qsh.set_normal_positive()
qsh.unbias_mean(0.5, 'te')
qsh.set_normal_positive()

print("QSH rebalanced 15 points size: ", len(qsh))
# Out:
# QSH rebalanced 15 points size:  7756

# %%
from bokeh.io import show, output_notebook
output_notebook()

qsh.set_null(-1)
m = Htls.tSNE()
# m.perplexity = 50.
m.random = 42

ds = qsh[range(0,4000)]
dsc = np.concatenate([ds['prel'],ds['te']], axis=1)
# dsc = np.array(list(zip(ds['prel'],ds['te'])))
m(dsc)

p = Hsne.tSNE_PlotBokeh()
p.set_model(m)
p.set_data(qsh, 1000)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1128">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:41163/autoload.js?bokeh-autoload-element=1255&bokeh-absolute-url=http://172.17.0.2:41163&resources=none" id="1255"></script>

# %%
qsh.set_null(np.nan)
qsh.clip_values(0.1,0.4)
qsh.set_normal_positive()

# %%
# FIT MODEL
vae = aefit.AEFIT(latent_dim=2, feature_dim=30)
# Out:
# aefit 0 configured

# %%
aefit.test_dummy(vae, qsh, batch=200, epoch=10)
# Out:
# 0-20 loss: 17.466394
# 1-40 loss: 17.047606
# 1-60 loss: 16.769424
# 2-80 loss: 16.430758
# 2-100 loss: 16.473543
# 3-120 loss: 16.442249
# 3-140 loss: 16.383396
# 4-160 loss: 16.503107
# 4-180 loss: 16.405516
# 5-200 loss: 16.411528
# 5-220 loss: 16.415289
# 6-240 loss: 16.371391
# 6-260 loss: 16.428213
# 7-280 loss: 16.455132
# 7-300 loss: 16.438843
# 8-320 loss: 16.466114
# 8-340 loss: 16.428349
# 9-360 loss: 16.443365
# 9-380 loss: 16.444935

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hplt.LSPlotBokeh()
p.set_model(vae)
p.set_data(qsh)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="47875">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:36535/autoload.js?bokeh-autoload-element=47970&bokeh-absolute-url=http://172.17.0.2:36535&resources=none" id="47970"></script>

# %% [markdown]
# ## Test the same with a dummy mockup

# %%
import Dummy_g1data as dummy

# %%
ds = dummy.Dummy_g1data(7000)
ds.kinds =  [
    {'mean': [0.5], 'sigma': [0.4], 'gain': [0.5]},
    {'mean': [0.5], 'sigma': [0.5], 'gain': [0.7]},    
]
dummy.test_gendata(ds)

# %%
d_vae = aefit.AEFIT(latent_dim=4, feature_dim=40)
# Out:
# aefit 0 configured new

# %%
aefit.test_dummy(d_vae, ds, batch=100, epoch=10)
# Out:
# 0-20 loss: 24.797712
# 0-40 loss: 24.375338
# 0-60 loss: 24.224957
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-14d264613de2> in <module>()
# ----> 1 aefit.test_dummy(d_vae, ds, batch=100, epoch=100)
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/AEFIT0.py in test_dummy(model, data, epoch, batch, loss_factor)
#     450         for X in ds:
#     451                 X_data,_ = X
# --> 452                 gradients, loss = compute_gradients(model, X_data)
#     453                 apply_gradients(optimizer, gradients, model.trainable_variables)
#     454                 count += 1
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/AEFIT0.py in compute_gradients(model, x)
#     416 def compute_gradients(model, x):
#     417     with tf.GradientTape() as tape:
# --> 418         loss = model.compute_loss(x)
#     419     return tape.gradient(loss, model.trainable_variables), loss
#     420
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/AEFIT0.py in compute_loss(self, input)
#     388         mean,logv = self.encode(xy)
#     389         z = self.reparameterize(mean,logv)
# --> 390         XY = self.decode(z)
#     391         XY = tf.where(att, tf.zeros_like(XY), XY)
#     392         #
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/AEFIT0.py in decode(self, s, apply_sigmoid)
#     374
#     375     def decode(self, s, apply_sigmoid=False):
# --> 376         x = self.generative_net(s)
#     377         if apply_sigmoid:
#     378             x = tf.sigmoid(x)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     710           with base_layer_utils.autocast_context_manager(
#     711               input_list, self._mixed_precision_policy.should_cast_variables):
# --> 712             outputs = self.call(inputs, *args, **kwargs)
#     713           self._handle_activity_regularization(inputs, outputs)
#     714           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     246       if not self.built:
#     247         self._init_graph_network(self.inputs, self.outputs, name=self.name)
# --> 248       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     249
#     250     outputs = inputs  # handle the corner case where self.layers is empty
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py in call(self, inputs, training, mask)
#     751                                 ' implement a `call` method.')
#     752
# --> 753     return self._run_internal_graph(inputs, training=training, mask=mask)
#     754
#     755   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask)
#     893
#     894           # Compute outputs.
# --> 895           output_tensors = layer(computed_tensors, **kwargs)
#     896
#     897           # Update tensor_dict.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     710           with base_layer_utils.autocast_context_manager(
#     711               input_list, self._mixed_precision_policy.should_cast_variables):
# --> 712             outputs = self.call(inputs, *args, **kwargs)
#     713           self._handle_activity_regularization(inputs, outputs)
#     714           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py in call(self, inputs)
#    1046       if not self._mixed_precision_policy.should_cast_variables:
#    1047         inputs = math_ops.cast(inputs, self.dtype)
# -> 1048       outputs = gen_math_ops.mat_mul(inputs, self.kernel)
#    1049     if self.use_bias:
#    1050       outputs = nn.bias_add(outputs, self.bias)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5899         _ctx._context_handle, _ctx._thread_local_data.device_name, "MatMul",
#    5900         name, _ctx._post_execution_callbacks, a, b, "transpose_a",
# -> 5901         transpose_a, "transpose_b", transpose_b)
#    5902       return _result
#    5903     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hplt.LSPlotBokeh()
p.set_model(d_vae)
p.set_data(ds)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="122309">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:46091/autoload.js?bokeh-autoload-element=122416&bokeh-absolute-url=http://172.17.0.2:46091&resources=none" id="122416"></script>
# E0626 16:02:19.456176 140116201248576 protocol_handler.py:102] error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '122370'}, 'attr': 'value', 'new': 'NaN,NaN'}], 'references': []}: InvalidArgumentError()
