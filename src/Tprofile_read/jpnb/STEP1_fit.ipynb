# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
from sklearn import datasets
from sklearn import metrics
from sklearn import model_selection
from sklearn import preprocessing

import tensorflow as tf
import abc

# %matplotlib inline
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors 

import ipysh
import Hunch_utils as Hunch
import Dummy_g1data as dummy
import models.AEFIT as aefit

plt.ion()
plt.show()
# Out:
# reload set for module  Hunch_utils
# reload set for module  models.AEFIT
# reload set for module  models.SPFIT

# %%
ds = dummy.Dummy_g1data()

m = aefit.AEFIT(latent_dim=2)

# %%
aefit.test_dummy(m)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# DATA READY:
# <img src="data:image/png;base64,..." width="639.999990463257">
# 0-20 loss: 21.770025
# 0-40 loss: 21.716946
# 0-60 loss: 21.924883
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-694eae0d02ab> in <module>
# ----> 1 aefit.test_dummy(m)
#
# ~/devel/rfx/rfx-hunch/src/Tprofile_read/models/AEFIT.py in test_dummy(model, data, counts, epoch, batch, loss_factor)
#     200                     for i in range(batch):
#     201                         # sns.scatterplot(X[i],Y[i])
# --> 202                         ax2.plot(X[i],Y[i],'.')
#     203                 #     # plt.figure(2)
#     204                 #     # plt.clf()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1610
#    1611         for line in self._get_lines(*args, **kwargs):
# -> 1612             self.add_line(line)
#    1613             lines.append(line)
#    1614
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1893             line.set_clip_path(self.patch)
#    1894
# -> 1895         self._update_line_limits(line)
#    1896         if not line.get_label():
#    1897             line.set_label('_line%d' % len(self.lines))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1915         Figures out the data limit of the given line, updating self.dataLim.
#    1916         """
# -> 1917         path = line.get_path()
#    1918         if path.vertices.size == 0:
#    1919             return
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/lines.py in get_path(self)
#     943         """
#     944         if self._invalidy or self._invalidx:
# --> 945             self.recache()
#     946         return self._path
#     947
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/lines.py in recache(self, always)
#     642             x = self._x
#     643         if always or self._invalidy:
# --> 644             yconv = self.convert_yunits(self._yorig)
#     645             y = _to_unmasked_float_array(yconv).ravel()
#     646         else:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in convert_yunits(self, y)
#     193         if ax is None or ax.yaxis is None:
#     194             return y
# --> 195         return ax.yaxis.convert_units(y)
#     196
#     197     @property
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axis.py in convert_units(self, x)
#    1519     def convert_units(self, x):
#    1520         # If x is already a number, doesn't need converting
# -> 1521         if munits.ConversionInterface.is_numlike(x):
#    1522             return x
#    1523
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/units.py in is_numlike(x)
#     124         """
#     125         if iterable(x):
# --> 126             for thisx in x:
#     127                 return isinstance(thisx, Number)
#     128         else:
#
# ~/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __iter__(self)
#     458           "Cannot iterate over a tensor with unknown first dimension.")
#     459     for i in xrange(shape[0]):
# --> 460       yield self[i]
#     461
#     462   def _shape_as_list(self):
#
# ~/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     667         ellipsis_mask=ellipsis_mask,
#     668         var=var,
# --> 669         name=name)
#     670
#     671
#
# ~/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#     833       ellipsis_mask=ellipsis_mask,
#     834       new_axis_mask=new_axis_mask,
# --> 835       shrink_axis_mask=shrink_axis_mask)
#     836
#     837   parent_name = name
#
# ~/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#    9791         end, strides, "begin_mask", begin_mask, "end_mask", end_mask,
#    9792         "ellipsis_mask", ellipsis_mask, "new_axis_mask", new_axis_mask,
# -> 9793         "shrink_axis_mask", shrink_axis_mask)
#    9794       return _result
#    9795     except _core._FallbackException:
#
# KeyboardInterrupt:
