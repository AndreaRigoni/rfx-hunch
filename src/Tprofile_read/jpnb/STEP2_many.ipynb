# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors 
# %matplotlib notebook

import ipysh
import Dummy_g1data as dummy
import Hunch_utils  as Htls
import Hunch_lsplot as Hplt

# %aimport models.AEFIT

# %% [markdown]
# # 7G X-strafe

# %%
ds = dummy.Dummy_g1data(counts=10000)
ds.kinds =  [
    {'mean': [0.8], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.7], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.6], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.4], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.3], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.2], 'sigma': [0.1], 'gain': [0.5]},    
]
ds.buffer()
dummy.test_gendata(ds)
# Out:
# <img src="data:image/png;base64,..." width="638.9999809563166">

# %%
m = models.AEFIT.AEFIT(40,2, beta=0.)
# Out:
# AEFIT5 ready:

# %%
# aefit.test_dummy(m, data=ds, epoch=5, batch=200, loss_factor=1e-3)
m.train_thread(ds).control_panel()
# m.save('kcp/step2_t3')
# m.load('kcp/step2_t3')
# Out:
# EPOCH:  0
# W0828 15:47:58.185274 139640694634240 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:182: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# test loss:  17.466455818
# EPOCH:  1

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hplt.LSPlotBokeh()
p.set_model(m)
p.set_data(ds)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# it: 1 - loss: 17.585979
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1319">Loading BokehJS ...</span>
#     </div>
# it: 2 - loss: 17.844538
# <script src="http://172.17.0.2:45693/autoload.js?bokeh-autoload-element=1320&bokeh-absolute-url=http://172.17.0.2:45693&resources=none" id="1320"></script>
# test loss:  15.914292341
# EPOCH:  2
# test loss:  15.470562133
# EPOCH:  3
# test loss:  15.397605355
# EPOCH:  4
# test loss:  15.392274844
# EPOCH:  5
# test loss:  15.387385487
# EPOCH:  6
# test loss:  15.372471585
# EPOCH:  7
# test loss:  15.362759056
# EPOCH:  8
# test loss:  15.353639712
# EPOCH:  9
# test loss:  15.343803221

# %% [markdown]
# # 7+7G XY-strafe

# %%
ds = dummy.Dummy_g1data(counts=10000)
ds.kinds =  [
    {'mean': [0.8], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.7], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.6], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.4], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.3], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.2], 'sigma': [0.1], 'gain': [0.2]},    

    {'mean': [0.8], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.7], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.6], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.4], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.3], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.2], 'sigma': [0.1], 'gain': [1.]},    
]
ds.buffer()
dummy.test_gendata(ds)

m = models.AEFIT.AEFIT(latent_dim=2, beta=0.)
# Out:
# AEFIT5 ready:

# %%
# aefit.test_dummy(m, data=ds, epoch=5, batch=200, loss_factor=1e-3)
m.train(ds)
# m.save('kcp/step2_t4')
# m.load('kcp/step2_t4')
# Out:
# EPOCH:  0
# test loss:  17.690832645
# EPOCH:  1
# test loss:  15.981221424
# EPOCH:  2
# test loss:  15.081064795
# EPOCH:  3
# test loss:  14.823033601
# EPOCH:  4
# test loss:  14.748364103
# EPOCH:  5
# it: 9 - loss: 14.791330
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-205985b88d49> in <module>()
#       1 # aefit.test_dummy(m, data=ds, epoch=5, batch=200, loss_factor=1e-3)
# ----> 2 m.train(ds)
#       3 # m.save('kcp/step2_t4')
#       4 # m.load('kcp/step2_t4')
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/base.py in train(self, dataset, epoch, batch, learning_rate)
#      59             print('EPOCH: ',e)
#      60             for i,data in enumerate(dt.batch(batch, drop_remainder=True)):
# ---> 61                 loss = self.train_step(data)
#      62                 sys.stdout.write('it: %d - loss: %f \r'%(i,loss))
#      63                 if self.stop_training:
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/AEFIT5.py in train_step(self, data, training)
#     219         with tf.GradientTape() as tape:
#     220             XY = self.call(xy, training=training)
# --> 221             loss = tf.reduce_mean( self.loss(xy, XY) + self.losses[0] )
#     222         if training:
#     223             gradients = tape.gradient(loss, self.trainable_variables)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in losses(self)
#     818       if loss_tensor is not None:
#     819         collected_losses.append(loss_tensor)
# --> 820     return collected_losses + self._gather_children_attribute('losses')
#     821
#     822   @doc_controls.for_subclass_implementers
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in _gather_children_attribute(self, attribute)
#    2109     if hasattr(self, '_layers'):
#    2110       nested_layers = trackable_layer_utils.filter_empty_layer_containers(
# -> 2111           self._layers)
#    2112       return list(
#    2113           itertools.chain.from_iterable(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/layer_utils.py in filter_empty_layer_containers(layer_list)
#      53     if is_layer(obj):
#      54       filtered.append(obj)
# ---> 55     elif hasattr(obj, "layers"):
#      56       # Trackable data structures will not show up in ".layers" lists, but
#      57       # the layers they contain will.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/data_structures.py in layers(self)
#     186   @property
#     187   def layers(self):
# --> 188     return layer_utils.filter_empty_layer_containers(self._layers)
#     189
#     190   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/data_structures.py in _layers(self)
#     178     collected = []
#     179     for obj in self._values:
# --> 180       if (isinstance(obj, TrackableDataStructure)
#     181           or layer_utils.is_layer(obj)
#     182           or layer_utils.has_weights(obj)):
#
# KeyboardInterrupt:

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hplt.LSPlotBokeh()
p.set_model(m)
p.set_data(ds)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="12676">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="13036">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:43699/autoload.js?bokeh-autoload-element=13037&bokeh-absolute-url=http://172.17.0.2:43699&resources=none" id="13037"></script>

# %%
ds = dummy.Dummy_g1data(counts=60000)
ds.kinds =  [
    {'mean': [0.8], 'sigma': [0.02], 'gain': [0.2]},
    {'mean': [0.7], 'sigma': [0.02], 'gain': [0.2]},
    {'mean': [0.6], 'sigma': [0.02], 'gain': [0.2]},
    {'mean': [0.5], 'sigma': [0.02], 'gain': [0.2]},
    {'mean': [0.4], 'sigma': [0.02], 'gain': [0.2]},
    {'mean': [0.3], 'sigma': [0.02], 'gain': [0.2]},
    {'mean': [0.2], 'sigma': [0.02], 'gain': [0.2]},    

    {'mean': [0.8], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.7], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.6], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.4], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.3], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.2], 'sigma': [0.1], 'gain': [1.]},    
]
dummy.test_gendata(ds)
m = aefit.AEFIT(latent_dim=2)

# %%
# aefit.test_dummy(m, data=ds, epoch=5, batch=200, loss_factor=1e-3)
# m.save('kcp/step2_t5')
m.load('kcp/step2_t5')
# Out:
# E0610 10:01:37.967258 140551817860928 web.py:1670] Uncaught exception GET /autoload.js?bokeh-autoload-element=1109&bokeh-absolute-url=http://172.17.0.2:41253&resources=none (172.17.0.1)
# HTTPServerRequest(protocol='http', host='172.17.0.2:41253', method='GET', uri='/autoload.js?bokeh-autoload-element=1109&bokeh-absolute-url=http://172.17.0.2:41253&resources=none', version='HTTP/1.1', remote_ip='172.17.0.1')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/tornado/web.py", line 1592, in _execute
#     result = yield result
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/autoload_js_handler.py", line 60, in get
#     session = yield self.get_session()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/session_handler.py", line 77, in get_session
#     session = yield self.application_context.create_session_if_needed(session_id, self.request)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/contexts.py", line 215, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/application.py", line 178, in initialize_document
#     h.modify_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/handlers/function.py", line 133, in modify_document
#     self._func(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 98, in plot
#     doc.add_root(self._layout)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 304, in add_root
#     self._pop_all_models_freeze()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1019, in _pop_all_models_freeze
#     self._recompute_all_models()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1042, in _recompute_all_models
#     a._attach_document(self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 714, in _attach_document
#     raise RuntimeError("Models must be owned by only a single document, %r is already in a doc" % (self))
# RuntimeError: Models must be owned by only a single document, Selection(id='1236', ...) is already in a doc
# E0610 10:01:37.975542 140551817860928 web.py:2162] 500 GET /autoload.js?bokeh-autoload-element=1109&bokeh-absolute-url=http://172.17.0.2:41253&resources=none (172.17.0.1) 14.05ms
# E0610 10:01:38.036043 140551817860928 web.py:1670] Uncaught exception GET /autoload.js?bokeh-autoload-element=1212&bokeh-absolute-url=http://172.17.0.2:34483&resources=none (172.17.0.1)
# HTTPServerRequest(protocol='http', host='172.17.0.2:34483', method='GET', uri='/autoload.js?bokeh-autoload-element=1212&bokeh-absolute-url=http://172.17.0.2:34483&resources=none', version='HTTP/1.1', remote_ip='172.17.0.1')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/tornado/web.py", line 1592, in _execute
#     result = yield result
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/autoload_js_handler.py", line 60, in get
#     session = yield self.get_session()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/session_handler.py", line 77, in get_session
#     session = yield self.application_context.create_session_if_needed(session_id, self.request)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/contexts.py", line 215, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/application.py", line 178, in initialize_document
#     h.modify_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/handlers/function.py", line 133, in modify_document
#     self._func(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 98, in plot
#     doc.add_root(self._layout)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 304, in add_root
#     self._pop_all_models_freeze()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1019, in _pop_all_models_freeze
#     self._recompute_all_models()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1042, in _recompute_all_models
#     a._attach_document(self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 714, in _attach_document
#     raise RuntimeError("Models must be owned by only a single document, %r is already in a doc" % (self))
# RuntimeError: Models must be owned by only a single document, Grid(id='1129', ...) is already in a doc
# E0610 10:01:38.037513 140551817860928 web.py:2162] 500 GET /autoload.js?bokeh-autoload-element=1212&bokeh-absolute-url=http://172.17.0.2:34483&resources=none (172.17.0.1) 7.24ms
# E0610 10:01:38.089166 140551817860928 web.py:1670] Uncaught exception GET /autoload.js?bokeh-autoload-element=5646&bokeh-absolute-url=http://172.17.0.2:42363&resources=none (172.17.0.1)
# HTTPServerRequest(protocol='http', host='172.17.0.2:42363', method='GET', uri='/autoload.js?bokeh-autoload-element=5646&bokeh-absolute-url=http://172.17.0.2:42363&resources=none', version='HTTP/1.1', remote_ip='172.17.0.1')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/tornado/web.py", line 1592, in _execute
#     result = yield result
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/autoload_js_handler.py", line 60, in get
#     session = yield self.get_session()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/session_handler.py", line 77, in get_session
#     session = yield self.application_context.create_session_if_needed(session_id, self.request)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/contexts.py", line 215, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/application.py", line 178, in initialize_document
#     h.modify_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/handlers/function.py", line 133, in modify_document
#     self._func(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 98, in plot
#     doc.add_root(self._layout)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 304, in add_root
#     self._pop_all_models_freeze()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1019, in _pop_all_models_freeze
#     self._recompute_all_models()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1042, in _recompute_all_models
#     a._attach_document(self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 714, in _attach_document
#     raise RuntimeError("Models must be owned by only a single document, %r is already in a doc" % (self))
# RuntimeError: Models must be owned by only a single document, UnionRenderers(id='5661', ...) is already in a doc
# E0610 10:01:38.090496 140551817860928 web.py:2162] 500 GET /autoload.js?bokeh-autoload-element=5646&bokeh-absolute-url=http://172.17.0.2:42363&resources=none (172.17.0.1) 7.82ms
# E0610 10:01:38.140683 140551817860928 web.py:1670] Uncaught exception GET /autoload.js?bokeh-autoload-element=40687&bokeh-absolute-url=http://172.17.0.2:41205&resources=none (172.17.0.1)
# HTTPServerRequest(protocol='http', host='172.17.0.2:41205', method='GET', uri='/autoload.js?bokeh-autoload-element=40687&bokeh-absolute-url=http://172.17.0.2:41205&resources=none', version='HTTP/1.1', remote_ip='172.17.0.1')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/tornado/web.py", line 1592, in _execute
#     result = yield result
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/autoload_js_handler.py", line 60, in get
#     session = yield self.get_session()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/session_handler.py", line 77, in get_session
#     session = yield self.application_context.create_session_if_needed(session_id, self.request)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/contexts.py", line 215, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/application.py", line 178, in initialize_document
#     h.modify_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/handlers/function.py", line 133, in modify_document
#     self._func(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 98, in plot
#     doc.add_root(self._layout)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 304, in add_root
#     self._pop_all_models_freeze()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1019, in _pop_all_models_freeze
#     self._recompute_all_models()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1042, in _recompute_all_models
#     a._attach_document(self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 714, in _attach_document
#     raise RuntimeError("Models must be owned by only a single document, %r is already in a doc" % (self))
# RuntimeError: Models must be owned by only a single document, ColumnDataSource(id='40621', ...) is already in a doc
# E0610 10:01:38.142581 140551817860928 web.py:2162] 500 GET /autoload.js?bokeh-autoload-element=40687&bokeh-absolute-url=http://172.17.0.2:41205&resources=none (172.17.0.1) 9.89ms
# E0610 10:01:38.176959 140551817860928 web.py:1670] Uncaught exception GET /autoload.js?bokeh-autoload-element=41735&bokeh-absolute-url=http://172.17.0.2:37559&resources=none (172.17.0.1)
# HTTPServerRequest(protocol='http', host='172.17.0.2:37559', method='GET', uri='/autoload.js?bokeh-autoload-element=41735&bokeh-absolute-url=http://172.17.0.2:37559&resources=none', version='HTTP/1.1', remote_ip='172.17.0.1')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/tornado/web.py", line 1592, in _execute
#     result = yield result
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/autoload_js_handler.py", line 60, in get
#     session = yield self.get_session()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/views/session_handler.py", line 77, in get_session
#     session = yield self.application_context.create_session_if_needed(session_id, self.request)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1133, in run
#     value = future.result()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/contexts.py", line 215, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/application.py", line 178, in initialize_document
#     h.modify_document(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/application/handlers/function.py", line 133, in modify_document
#     self._func(doc)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 98, in plot
#     doc.add_root(self._layout)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 304, in add_root
#     self._pop_all_models_freeze()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1019, in _pop_all_models_freeze
#     self._recompute_all_models()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1042, in _recompute_all_models
#     a._attach_document(self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 714, in _attach_document
#     raise RuntimeError("Models must be owned by only a single document, %r is already in a doc" % (self))
# RuntimeError: Models must be owned by only a single document, Line(id='41671', ...) is already in a doc
# E0610 10:01:38.178864 140551817860928 web.py:2162] 500 GET /autoload.js?bokeh-autoload-element=41735&bokeh-absolute-url=http://172.17.0.2:37559&resources=none (172.17.0.1) 9.61ms

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hplt.LSPlotBokeh()
p.set_model(m)
p.set_data(ds)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="41561">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:37559/autoload.js?bokeh-autoload-element=41735&bokeh-absolute-url=http://172.17.0.2:37559&resources=none" id="41735"></script>
