# %%
import numpy as np
import tensorflow as tf

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors 

import ipysh
import Hunch_utils  as Htls
import Hunch_lsplot as Hplt
import Hunch_tSNEplot as Hsne

# %aimport Dataset_QSH

# %aimport models.base
# %aimport models.AEFIT5
# %aimport models.CAEFIT
# %aimport models.CAEFIT1



import livelossplot.keras
class PlotLossesCallback(livelossplot.keras.PlotLossesCallback):
    def on_train_batch_begin(self, a, b): pass
    def on_train_batch_end(self, a, b): pass
    def on_test_begin(self, a): pass
    def on_test_end(self, a): pass
    def on_test_batch_begin(self, a, b): pass
    def on_test_batch_end(self, a, b): pass

# %%
qsh = Dataset_QSH.Dataset_QSH()
import os
file = ipysh.abs_builddir+'/te_db_r15u.npy'
if os.path.isfile(file):
    qsh.load(file)
else:
    qsh.load(ipysh.abs_builddir+'/te_db_1.npy')    
    qsh.rebalance_prel(15)
    qsh.save(ipysh.abs_builddir+'/te_db_r15u.npy')

# %%
qsh.shuffle()
# qsh.filter_number_set(15)
qsh.clean_up_poorcurves(5)
qsh.dim = 15
qsh.set_null(np.nan)
qsh.set_normal_positive()
# qsh.unbias_mean(0.5, 'te')
# qsh.set_normal_positive()

print("QSH rebalanced 15 points size: ", len(qsh))
# Out:
# QSH rebalanced 15 points size:  47567

# %%
# qsh.set_null(np.nan)
# qsh.clip_values(0.1,0.6)
# qsh.set_normal_positive()
# qsh.set_null(np.nan)

# %% [markdown]
# ## t-SNE Plot

# %%
qsh.set_null(-1)
sne = Htls.tSNE()
# sne.perplexity = 50.
sne.random = 42

ds = qsh[range(0,4000)]
ds = np.concatenate([ds['prel'],ds['te']], axis=1)
# ds = np.array(list(zip(ds['prel'],ds['te'])))
sne(ds)
qsh.set_null(np.nan)

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hsne.tSNE_PlotBokeh()
p.set_model(sne)
p.set_data(qsh, 1000)
p.plot(notebook_url='http://172.17.0.2:8888')

# %% [markdown]
# ## VAE reconstruction - beta
#
# The dropout has been set to 0. ... otherwise it seems to not converge ( tested with 0.4 )
# Moreover also beta has been set to 0. ... that corresponds to a deterministic vae

# %%
# %aimport models.base
#%aimport models.AEFIT2
# %aimport models.AEFIT3
# q_vae = models.AEFIT2.AEFIT2(latent_dim=2, feature_dim=30, dprate=0., scale=4, beta=0.)
q_vae = models.AEFIT5.AEFIT5(latent_dim=2, feature_dim=30, dprate=0., scale=1, beta=0.000001, geometry=[20,20,10,10])
# im1 = tf.keras.utils.plot_model(q_vae.inference_net, show_shapes=True, rankdir='LR')
# im2 = tf.keras.utils.plot_model(q_vae.generative_net, show_shapes=True, rankdir='LR')
# from IPython.display import display
# display(im1)
# display(im2)
# q_vae.compile( tf.optimizers.Adam(1e-3), tf.losses.mse )
# q_vae.compile( tf.optimizers.Adam(1e-3), q_vae.compute_cross_entropy_loss )
# Out:
# AEFIT5 a ready:

# %%
p = Hplt.LSPlotBokeh()
p.set_model(q_vae)
p.set_data(qsh, counts=1000)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5738">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:35445/autoload.js?bokeh-autoload-element=5739&bokeh-absolute-url=http://172.17.0.2:35445&resources=none" id="5739"></script>

# %%
ds = qsh.ds_array.map(lambda x,l: (x,x))

# %%
#models.base.manual_train_thread(q_vae, qsh, batch=200, epoch=6, loss_factor=1e-3)
# q_vae.train_thread(qsh, batch=200, epoch=10, learning_rate=1e-3).control_panel()
# models.base.train_thread(q_vae, qsh, batch=100, epoch=10, learning_rate=1e-3, callbacks=[]).control_panel()
def fun():
    global h
    h = q_vae.fit( ds.skip(3000).batch(100, drop_remainder=True), validation_data=ds.take(3000).batch(100), epochs=200, shuffle=False)
models.base.fn_thread(fn=fun, model=q_vae).control_panel()
# Out:
# Epoch 1/200
# 445/445 [==============================] - 16s 36ms/step - loss: 0.0028 - val_loss: 0.0000e+00
# Epoch 2/200
# 445/445 [==============================] - 13s 28ms/step - loss: 2.2950e-04 - val_loss: 1.8617e-04
# Epoch 3/200
# 445/445 [==============================] - 11s 24ms/step - loss: 2.0176e-04 - val_loss: 2.0772e-04
# Epoch 4/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.9608e-04 - val_loss: 1.9355e-04
# Epoch 5/200
# 445/445 [==============================] - 12s 27ms/step - loss: 1.9151e-04 - val_loss: 2.0219e-04
# Epoch 6/200
# 445/445 [==============================] - 11s 25ms/step - loss: 1.8931e-04 - val_loss: 1.8123e-04
# Epoch 7/200
# 445/445 [==============================] - 11s 24ms/step - loss: 1.8756e-04 - val_loss: 1.8886e-04
# Epoch 8/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.8681e-04 - val_loss: 1.9126e-04
# Epoch 9/200
# 445/445 [==============================] - 10s 24ms/step - loss: 1.8179e-04 - val_loss: 1.8623e-04
# Epoch 10/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.8308e-04 - val_loss: 1.7169e-04
# Epoch 11/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7973e-04 - val_loss: 1.6450e-04
# Epoch 12/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7679e-04 - val_loss: 1.6842e-04
# Epoch 13/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7580e-04 - val_loss: 1.6605e-04
# Epoch 14/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7453e-04 - val_loss: 1.6182e-04
# Epoch 15/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7364e-04 - val_loss: 1.6988e-04
# Epoch 16/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7220e-04 - val_loss: 1.7139e-04
# Epoch 17/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7043e-04 - val_loss: 1.6620e-04
# Epoch 18/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6878e-04 - val_loss: 1.6141e-04
# Epoch 19/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6910e-04 - val_loss: 1.7252e-04
# Epoch 20/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6896e-04 - val_loss: 1.7098e-04
# Epoch 21/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6946e-04 - val_loss: 1.5739e-04
# Epoch 22/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6688e-04 - val_loss: 1.5851e-04
# Epoch 23/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6764e-04 - val_loss: 1.5859e-04
# Epoch 24/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6839e-04 - val_loss: 1.6519e-04
# Epoch 25/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6635e-04 - val_loss: 1.5317e-04
# Epoch 26/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7309e-04 - val_loss: 1.7790e-04
# Epoch 27/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6770e-04 - val_loss: 1.5735e-04
# Epoch 28/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6713e-04 - val_loss: 1.7120e-04
# Epoch 29/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6823e-04 - val_loss: 1.7139e-04
# Epoch 30/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6446e-04 - val_loss: 1.8699e-04
# Epoch 31/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7765e-04 - val_loss: 1.6216e-04
# Epoch 32/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6846e-04 - val_loss: 1.5629e-04
# Epoch 33/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6714e-04 - val_loss: 1.4905e-04
# Epoch 34/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6543e-04 - val_loss: 1.6977e-04
# Epoch 35/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.
200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6247e-04 - val_loss: 1.6118e-04
# Epoch 132/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6212e-04 - val_loss: 1.6202e-04
# Epoch 133/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6128e-04 - val_loss: 1.5552e-04
# Epoch 134/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5742e-04 - val_loss: 1.5366e-04
# Epoch 135/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5969e-04 - val_loss: 1.5393e-04
# Epoch 136/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5785e-04 - val_loss: 1.5223e-04
# Epoch 137/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5371e-04 - val_loss: 1.5611e-04
# Epoch 138/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5500e-04 - val_loss: 1.5661e-04
# Epoch 139/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5855e-04 - val_loss: 1.5445e-04
# Epoch 140/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5698e-04 - val_loss: 1.5868e-04
# Epoch 141/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5488e-04 - val_loss: 1.5033e-04
# Epoch 142/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5483e-04 - val_loss: 1.5914e-04
# Epoch 143/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5456e-04 - val_loss: 1.4716e-04
# Epoch 144/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6033e-04 - val_loss: 1.5992e-04
# Epoch 145/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5910e-04 - val_loss: 1.5074e-04
# Epoch 146/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6204e-04 - val_loss: 1.5673e-04
# Epoch 147/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5785e-04 - val_loss: 1.6634e-04
# Epoch 148/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6552e-04 - val_loss: 1.5604e-04
# Epoch 149/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6517e-04 - val_loss: 1.6862e-04
# Epoch 150/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6363e-04 - val_loss: 1.5108e-04
# Epoch 151/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6325e-04 - val_loss: 1.7511e-04
# Epoch 152/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5655e-04 - val_loss: 1.5503e-04
# Epoch 153/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5503e-04 - val_loss: 1.7048e-04
# Epoch 154/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6007e-04 - val_loss: 1.7212e-04
# Epoch 155/200
# 445/445 [==============================] - 11s 24ms/step - loss: 1.5532e-04 - val_loss: 1.5061e-04
# Epoch 156/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5406e-04 - val_loss: 1.4692e-04
# Epoch 157/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6106e-04 - val_loss: 1.5834e-04
# Epoch 158/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6846e-04 - val_loss: 1.5498e-04
# Epoch 159/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6658e-04 - val_loss: 1.5319e-04
# Epoch 160/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.7079e-04 - val_loss: 1.8488e-04
# Epoch 161/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5551e-04 - val_loss: 1.4616e-04
# Epoch 162/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5194e-04 - val_loss: 1.5120e-04
# Epoch 163/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.8498e-04 - val_loss: 1.6791e-04
# Epoch 164/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.7680e-04 - val_loss: 1.8996e-04
# Epoch 165/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.7883e-04 - val_loss: 1.6999e-04
# Epoch 166/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.7333e-04 - val_loss: 1.6597e-04
# Epoch 167/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.7496e-04 - val_loss: 1.6769e-04
# Epoch 168/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6661e-04 - val_loss: 1.6177e-04
# Epoch 169/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6452e-04 - val_loss: 1.6197e-04
# Epoch 170/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6572e-04 - val_loss: 1.6149e-04
# Epoch 171/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6581e-04 - val_loss: 1.6148e-04
# Epoch 172/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6196e-04 - val_loss: 1.5754e-04
# Epoch 173/200
# 445/445 [==============================] - 10s 23ms/step - loss: 8.5844e-04 - val_loss: 5.1663e-04
# Epoch 174/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.9198e-04 - val_loss: 1.6599e-04
# Epoch 175/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6731e-04 - val_loss: 1.6673e-04
# Epoch 176/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.6997e-04 - val_loss: 1.6210e-04
# Epoch 177/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.6162e-04 - val_loss: 1.5866e-04
# Epoch 178/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5967e-04 - val_loss: 1.5631e-04
# Epoch 179/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5874e-04 - val_loss: 1.5531e-04
# Epoch 180/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5818e-04 - val_loss: 1.5453e-04
# Epoch 181/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5709e-04 - val_loss: 1.5331e-04
# Epoch 182/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5599e-04 - val_loss: 1.5107e-04
# Epoch 183/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5494e-04 - val_loss: 1.5455e-04
# Epoch 184/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5497e-04 - val_loss: 1.5690e-04
# Epoch 185/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5512e-04 - val_loss: 1.5334e-04
# Epoch 186/200
# 445/445 [==============================] - 11s 24ms/step - loss: 1.5356e-04 - val_loss: 1.5356e-04
# Epoch 187/200
# 445/445 [==============================] - 11s 24ms/step - loss: 1.5388e-04 - val_loss: 1.4968e-04
# Epoch 188/200
# 445/445 [==============================] - 11s 24ms/step - loss: 1.5361e-04 - val_loss: 1.4946e-04
# Epoch 190/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5589e-04 - val_loss: 1.5447e-04
# Epoch 191/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5496e-04 - val_loss: 1.5237e-04
# Epoch 192/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5249e-04 - val_loss: 1.5023e-04
# Epoch 193/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5299e-04 - val_loss: 1.5108e-04
# Epoch 194/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5304e-04 - val_loss: 1.4853e-04
# Epoch 195/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5274e-04 - val_loss: 1.4681e-04
# Epoch 196/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5932e-04 - val_loss: 1.5008e-04
# Epoch 197/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5539e-04 - val_loss: 1.4925e-04
# Epoch 198/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5631e-04 - val_loss: 1.5154e-04
# Epoch 199/200
# 445/445 [==============================] - 10s 23ms/step - loss: 1.5314e-04 - val_loss: 1.4908e-04
# Epoch 200/200
# 445/445 [==============================] - 10s 22ms/step - loss: 1.5856e-04 - val_loss: 1.4816e-04

# %%
loss = [i[0] for i in h.history['loss']]
val_loss = [i[0] for i in h.history['val_loss']]
fig = plt.figure('loss')
fig.set_dpi(150)
plt.yscale('log')
plt.plot(loss)
plt.plot(val_loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0885c2c1424d> in <module>()
# ----> 1 loss = [i[0] for i in h.history['loss']]
#       2 val_loss = [i[0] for i in h.history['val_loss']]
#       3 fig = plt.figure('loss')
#       4 fig.set_dpi(150)
#       5 plt.yscale('log')
#
# NameError: name 'h' is not defined

# %%
# q_vae.save('step7_beta0_r15_1')
q_vae.save('step7_beta0001_r15_ls2_1')

# %%
q_vae.load('step7_beta0_r15_1')

# %%
# extract few points curve
import copy

qsh2 = Dataset_QSH.Dataset_QSH()
qsh2.load(ipysh.abs_builddir+'/te_db_r15u.npy')
qsh2.dim = 15
qsh2.set_null(np.nan)
qsh2.set_normal_positive()
qsh2.unbias_mean(0.5, 'te')
qsh2.set_normal_positive()
qsh2.set_null(np.nan)
qsh2.clip_values(0.1,0.6)
qsh2.set_normal_positive()


qsh2.filter_number_set(5)
qsh2.dim = 15

# %%
pos = 0

# %%
fig = plt.figure('gen_missing_curve',figsize=(18, 6))
plt.clf()
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)    
# ax1.set_xlim(-2.,2.)
ax2.set_ylim(0.,1.5)

# print(q_vae.apply_sigmoid)
print(pos)
# qsh2.shuffle()
for xy in qsh.ds_array.skip(pos).batch(1).take(1):
    xy,_ = xy
    # print(xy)
    x,y = tf.split(xy[0],2)
    ax2.scatter(x,y,s=80)
    m,v  = q_vae.encode(xy, training=False)    
    gpt = m[0].numpy()
    # print(gpt)
    ax1.scatter(gpt[0],gpt[1])

    XY = q_vae.decode(m, training=False)
    X,Y = tf.split(XY[0], 2)
    X,Y = (X.numpy(), Y.numpy())

    ax2.scatter(X,Y,s=40)
pos += 1
